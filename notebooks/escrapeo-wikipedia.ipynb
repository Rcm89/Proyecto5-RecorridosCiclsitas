# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os

# %%
lista_carreras= ['del_Giro_de_Italia', 'del_Tour_de_Francia', 'de_la_Vuelta_a_España']

# %%
def escrapeo_wikipedia(lista_de_carreras):
    
    ruta_datos = '../datos/datos_wikipedia'
    os.makedirs(ruta_datos, exist_ok=True)

    lista_dataframes = []
    # Iteramos sobre cada una de las arreras de lista_de_carreras
    for carrera in lista_de_carreras:
        url = 'https://es.wikipedia.org/wiki/Anexo:Datos_estad%C3%ADsticos_' + carrera

        # Extraemos con Beautiful Soup la tabla de la url de arriba y la guardamos en un DataFrame
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')

        tabla = soup.find('table', {'class': 'wikitable'})

        # Verificamos que se ha encontrado una tabla en la página
        if tabla:
            encabezados = [encabezado.text.strip() for encabezado in tabla.find_all('th')]

            filas = []
            for fila in tabla.find_all('tr')[1:]:
                celdas = fila.find_all(['td', 'th'])
                celdas_text = [celda.text.strip() for celda in celdas]
                filas.append(celdas_text)

            df = pd.DataFrame(filas, columns=encabezados)

            # Definimos la ruta y el nombre del archivo CSV
            nombre_archivo = f'df_{carrera}.csv'
            ruta_archivo = os.path.join(ruta_datos, nombre_archivo)

            # Guardamos el DataFrame en un archivo CSV
            df.to_csv(ruta_archivo, index=False)

            # Agregamos el DataFrame a la lista
            lista_dataframes.append(df)
    
    return lista_dataframes

# %%
[df_giro, df_tour, df_vuelta] = escrapeo_wikipedia(lista_carreras)

# %%
df_giro.head()
# Out:
#   Edición   Año        Ganador Tiempo del ganador Kilómetros totales  \
# 0     1.ª  1909    Luigi Ganna            25 pts.              2.448
# 1     2.ª  1910  Carlo Galetti            28 pts.            2.987,5
# 2     3.ª  1911  Carlo Galetti            50 pts.              3.452
# 3     4.ª  1912          Atala            31 pts.            2.439,5
# 4     5.ª  1913   Carlo Oriani            37 pts.              2.932
#
#   Velocidad media (km/h) N.º de etapas[1]​ N.º de corredores que participaron  \
# 0                 27,258                 8                                127
# 1                 26,114                10                                101
# 2                 26,082                12                                 86
# 3                 27,106                 8                                 54
# 4                 26,379                 9                                 99
#
#   N.º de corredores que finalizaron
# 0                                49
# ...

# %%
df_tour.head()
# Out:
#   Edición   Año              Ganador Tiempo del ganador Kilómetros totales  \
# 0       1  1903        Maurice Garin         94:33’14’’              2.428
# 1       2  1904     Henri Cornet[2]​         96:05’55’’              2.428
# 2       3  1905    Louis Trousselier          35 puntos              2.994
# 3       4  1906         René Pottier          31 puntos              4.545
# 4       5  1907  Lucien Petit-Breton          47 puntos              4.488
#
#   Velocidad media N.º de etapas[1]​ N.º de corredores que participaron  \
# 0     25,679 km/h                 6                                 60
# 1     25,265 km/h                 6                                 80
# 2     25,265 km/h                11                                 60
# 3     24,463 km/h                13                                 82
# 4     28,740 km/h                14                                 93
#
#   N.º de corredores que finalizaron
# 0                                21
# ...

# %%
df_vuelta.head()
# Out:
#      Edición                                                Año  \
# 0    I (1.ª)                                               1935
# 1   II (2.ª)                                               1936
# 2  1937-1940  Ediciones suspendidas por la Guerra civil espa...
# 3  III (3.ª)                                               1941
# 4   IV (4.ª)                                               1942
#
#     Fecha(dd/mm)            Ganador Tiempo del ganador Kilómetros totales  \
# 0  29/04 - 15/05     Gustaaf Deloor        120:01’02’’               3425
# 1  05/05 - 31/05     Gustaaf Deloor        150:07’54’’               3407
# 2           None               None               None               None
# 3  12/06 - 06/07  Julián Berrendero        168:45’26’’               3406
# 4  30/06 - 19/07  Julián Berrendero        134:05’09’’               3688
#
#   Velocidad media N.º de Etapas[1]​ N.º de equipos participantes  \
# 0    28,537 km/h.                14                            -
# ...

# %% [markdown]
# Vamos a escrapear también cada edición del Giro, tour y Vuelga, el sigueinte cidoo sirve de modelo

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://es.wikipedia.org/wiki/Giro_de_Italia_1966"

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
tabla_etapas = soup.find('table', {'class': 'wikitable'})
encabezados = [header.text.strip() for header in tabla_etapas.find_all('th')]

filas = []
for row in tabla_etapas.find_all('tr')[1:]:  # Excluimos la primera fila que contiene los encabezados
    columnas = row.find_all(['td', 'th'])
    fila = [columna.text.strip() for columna in columnas]
    filas.append(fila)

df_etapas_wiki = pd.DataFrame(filas, columns=encabezados)

df_etapas_wiki.head()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File c:\Users\Administrador\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\construction.py:939, in _finalize_columns_and_data(content, columns, dtype)
#     938 try:
# --> 939     columns = _validate_or_indexify_columns(contents, columns)
#     940 except AssertionError as err:
#     941     # GH#26429 do not raise user-facing AssertionError
#
# File c:\Users\Administrador\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\construction.py:986, in _validate_or_indexify_columns(content, columns)
#     984 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#     985     # caller's responsibility to check for this...
# --> 986     raise AssertionError(
#     987         f"{len(columns)} columns passed, passed data had "
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://es.wikipedia.org/wiki/Giro_de_Italia_1966"

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
tabla_etapas = soup.find('table', {'class': '#mw-content-text > div.mw-content-ltr.mw-parser-output > table:nth-child(7)'})

# Verificación de que la tabla fue encontrada
if tabla_etapas is None:
    print("No se encontró la tabla en la página.")
else:
    encabezados = [header.text.strip() for header in tabla_etapas.find_all('th')]

    filas = []
    for row in tabla_etapas.find_all('tr')[1:]:  # Excluimos la primera fila que contiene los encabezados
        columnas = row.find_all(['td', 'th'])
        fila = [columna.text.strip() for columna in columnas]
        filas.append(fila)

    df_etapas_wiki = pd.DataFrame(filas, columns=encabezados)
    print(df_etapas_wiki.head())
# Out:
# No se encontró la tabla en la página.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import pandas as pd
import time

# Configura el controlador de Selenium (Chrome en este caso)
driver = webdriver.Chrome()  # Asegúrate de tener ChromeDriver instalado y en tu PATH

# Abre la página de Wikipedia
url = "https://es.wikipedia.org/wiki/Giro_de_Italia_1966"
driver.get(url)

# Espera a que la página cargue completamente (ajusta el tiempo si es necesario)
time.sleep(3)

# Obtén el HTML de la página
html = driver.page_source

# Cierra el navegador
driver.quit()

# Ahora usa BeautifulSoup para analizar el HTML
soup = BeautifulSoup(html, 'html.parser')

# Encuentra la tabla de las etapas usando BeautifulSoup
tabla_etapas = soup.find('table', {'class': 'wikitable'})

# Verificación de que la tabla fue encontrada
if tabla_etapas is None:
    print("No se encontró la tabla en la página.")
else:
    # Extrae encabezados
    encabezados = [header.text.strip() for header in tabla_etapas.find_all('th')]

    # Extrae filas
    filas = []
    for row in tabla_etapas.find_all('tr')[1:]:  # Excluimos la primera fila que contiene los encabezados
        columnas = row.find_all(['td', 'th'])
        fila = [columna.text.strip() for columna in columnas]
        filas.append(fila)

    # Crea el DataFrame
    df_etapas_wiki = pd.DataFrame(filas, columns=encabezados)
    print(df_etapas_wiki.head())
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File c:\Users\Administrador\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\construction.py:939, in _finalize_columns_and_data(content, columns, dtype)
#     938 try:
# --> 939     columns = _validate_or_indexify_columns(contents, columns)
#     940 except AssertionError as err:
#     941     # GH#26429 do not raise user-facing AssertionError
#
# File c:\Users\Administrador\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\construction.py:986, in _validate_or_indexify_columns(content, columns)
#     984 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#     985     # caller's responsibility to check for this...
# --> 986     raise AssertionError(
#     987         f"{len(columns)} columns passed, passed data had "
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL del artículo de Wikipedia
url = "https://es.wikipedia.org/wiki/Giro_de_Italia_1909"

# Realizamos la solicitud GET a la página
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# Encontramos todas las tablas en la página
tablas = soup.find_all('table')

# Iteramos sobre cada tabla y la convertimos en un DataFrame
dataframes = []
for i, tabla in enumerate(tablas):
    # Extraemos los encabezados de la tabla, si están presentes
    encabezados = [header.text.strip() for header in tabla.find_all('th')]

    # Extraemos las filas de la tabla
    filas = []
    for row in tabla.find_all('tr')[1:]:  # Excluye la primera fila si contiene encabezados
        columnas = row.find_all(['td', 'th'])
        fila = [columna.text.strip() for columna in columnas]
        filas.append(fila)

    # Creamos el DataFrame y lo añadimos a la lista
    if encabezados:
        df = pd.DataFrame(filas, columns=encabezados)
    else:
        df = pd.DataFrame(filas)
        
    dataframes.append(df)

# Mostramos las primeras filas de cada DataFrame
for idx, df in enumerate(dataframes):
    print(f"Tabla {idx + 1}")
    print(df.head())
    print("\n" + "-"*50 + "\n")
# Out:
# Tabla 1
#                      0                         1
# 0  Giro de Italia 1909
# 1             Detalles                      None
# 2              Carrera        1.  Giro de Italia
# 3               Etapas                         8
# 4               Fechas  13  – 30 de mayo de 1909
#
# --------------------------------------------------
#
# Tabla 2
# Empty DataFrame
# Columns: []
# Index: []
#
# --------------------------------------------------
#
# Tabla 3
#        Etapa      Fecha         Recorrido              type Distancia (km)  \
# 0  1.ª etapa  13 de may   Milán – Bolonia       etapa llana            397
# 1  2.ª etapa  16 de may  Bolonia – Chieti       etapa llana          378,5
# 2  3.ª etapa  18 de may  Chieti – Nápoles  etapa de montaña          242,8
# 3  4.ª etapa  20 de may    Nápoles – Roma       etapa llana          228,1
# 4  5.ª etapa  23 de may  Roma – Florencia       etapa llana          346,5
#
#                Ganador          Líder
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL del artículo de Wikipedia
url = "https://es.wikipedia.org/wiki/Giro_de_Italia_1909"

# Realizamos la solicitud GET a la página
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# Encontramos todas las tablas en la página
tablas = soup.find_all('table')

# Variable para almacenar el DataFrame de la tabla específica
df_etapas = None

# Iteramos sobre cada tabla y seleccionamos la que tiene "Etapa" como primer encabezado
for i, tabla in enumerate(tablas):
    # Extraemos los encabezados de la tabla, si están presentes
    encabezados = [header.text.strip() for header in tabla.find_all('th')]

    # Comprobamos si el primer encabezado es "Etapa"
    if encabezados and encabezados[0] == "Etapa":
        # Extraemos las filas de la tabla
        filas = []
        for row in tabla.find_all('tr')[1:]:  # Excluye la primera fila que contiene los encabezados
            columnas = row.find_all(['td', 'th'])
            fila = [columna.text.strip() for columna in columnas]
            filas.append(fila)

        # Creamos el DataFrame con los encabezados
        df_etapas = pd.DataFrame(filas, columns=encabezados)
        break  # Salimos del bucle al encontrar la tabla deseada

# Mostramos el DataFrame de la tabla "Etapas"
if df_etapas is not None:
    print("Tabla 'Etapas':")
    print(df_etapas.head())
else:
    print("No se encontró una tabla con el primer encabezado 'Etapas'.")
# Out:
# Tabla 'Etapas':
#        Etapa      Fecha         Recorrido              type Distancia (km)  \
# 0  1.ª etapa  13 de may   Milán – Bolonia       etapa llana            397
# 1  2.ª etapa  16 de may  Bolonia – Chieti       etapa llana          378,5
# 2  3.ª etapa  18 de may  Chieti – Nápoles  etapa de montaña          242,8
# 3  4.ª etapa  20 de may    Nápoles – Roma       etapa llana          228,1
# 4  5.ª etapa  23 de may  Roma – Florencia       etapa llana          346,5
#
#                Ganador          Líder
# 0           Dario Beni     Dario Beni
# 1     Giovanni Cuniolo    Luigi Ganna
# 2  Giovanni Rossignoli  Carlo Galetti
# 3          Luigi Ganna    Luigi Ganna
# 4          Luigi Ganna    Luigi Ganna

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL del artículo de Wikipedia
url = "https://es.wikipedia.org/wiki/Giro_de_Italia_1966"

# Realizamos la solicitud GET a la página
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# Encontramos todas las tablas en la página
tablas = soup.find_all('table')

# Variable para almacenar el DataFrame de la tabla deseada
df_etapa = None

# Iteramos sobre cada tabla y verificamos si contiene "Etapa" en los encabezados
for i, tabla in enumerate(tablas):
    # Extraemos los encabezados de la tabla, si están presentes
    encabezados = [header.text.strip() for header in tabla.find_all('th')]

    # Verificamos si "Etapa" está en los encabezados
    if "Etapa" in encabezados:
        # Extraemos las filas de la tabla
        filas = []
        for row in tabla.find_all('tr')[1:]:  # Excluye la primera fila si contiene encabezados
            columnas = row.find_all(['td', 'th'])
            fila = [columna.text.strip() for columna in columnas]
            filas.append(fila)

        # Creamos el DataFrame y asignamos los encabezados
        df_etapa = pd.DataFrame(filas, columns=encabezados)
        break  # Salimos del bucle una vez que encontramos la tabla
if df_etapa == None:
    # Encontramos todas las tablas con la clase 'wikitable'
    tablas = soup.find_all('table', {'class': 'wikitable'})

    # Lista para almacenar los DataFrames de cada tabla
    dataframes = []

    # Iteramos sobre cada tabla y la convertimos en un DataFrame
    for i, tabla in enumerate(tablas):
        # Extraemos los encabezados de la tabla, si están presentes
        encabezados = [header.text.strip() for header in tabla.find_all('th')]

        # Extraemos las filas de la tabla
        filas = []
        for row in tabla.find_all('tr')[1:]:  # Excluye la primera fila si contiene encabezados
            columnas = row.find_all(['td', 'th'])
            fila = [columna.text.strip() for columna in columnas]
            filas.append(fila)

        # Creamos el DataFrame y lo añadimos a la lista
        df = pd.DataFrame(filas, columns=encabezados) if encabezados else pd.DataFrame(filas)
        dataframes.append(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[60], line 36
#      33         df_etapa = pd.DataFrame(filas, columns=encabezados)
#      34         break  # Salimos del bucle una vez que encontramos la tabla
# ---> 36 df_etapa.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL del artículo de Wikipedia
url = "https://es.wikipedia.org/wiki/Tour_de_Francia_1938"

# Realizamos la solicitud GET a la página
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# Encontramos todas las tablas con la clase 'wikitable'
tablas = soup.find_all('table', {'class': 'wikitable'})

# Lista para almacenar los DataFrames de cada tabla
dataframes = []

# Iteramos sobre cada tabla y la convertimos en un DataFrame
for i, tabla in enumerate(tablas):
    # Extraemos los encabezados de la tabla, si están presentes
    encabezados = [header.text.strip() for header in tabla.find_all('th')]

    # Extraemos las filas de la tabla
    filas = []
    for row in tabla.find_all('tr')[1:]:  # Excluye la primera fila si contiene encabezados
        columnas = row.find_all(['td', 'th'])
        fila = [columna.text.strip() for columna in columnas]
        filas.append(fila)

    # Creamos el DataFrame y lo añadimos a la lista
    df = pd.DataFrame(filas, columns=encabezados) if encabezados else pd.DataFrame(filas)
    dataframes.append(df)

    # Mostramos las primeras filas de cada DataFrame
    print(f"Tabla {i + 1}")
    print(df.head())
    print("\n" + "-"*50 + "\n")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File c:\Users\Administrador\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\construction.py:939, in _finalize_columns_and_data(content, columns, dtype)
#     938 try:
# --> 939     columns = _validate_or_indexify_columns(contents, columns)
#     940 except AssertionError as err:
#     941     # GH#26429 do not raise user-facing AssertionError
#
# File c:\Users\Administrador\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\construction.py:986, in _validate_or_indexify_columns(content, columns)
#     984 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#     985     # caller's responsibility to check for this...
# --> 986     raise AssertionError(
#     987         f"{len(columns)} columns passed, passed data had "
# ...

# %%
dataframes
# Out:
# [       0                            1         2                     3  \
#  0    1.ª      Montecarlo-Diano Marina       149          Vito Taccone
#  1    2.ª               Imperia-Monesi        60         Julio Jiménez
#  2    3.ª          Diano Marina-Génova       120     Severino Andreoli
#  3    4.ª             Génova-Viareggio       241        Giovanni Knapp
#  4    5.ª   Viareggio-Chianciano Terme       222  Vendramino Bariviera
#  5    6.ª        Chianciano Terme-Roma       226      Raffaele Marcoli
#  6    7.ª         Roma-Rocca di Cambio       158            Rudi Altig
#  7    8.ª      Rocca di Cambio-Nápoles       238          Marino Basso
#  8    9.ª           Nápoles-Campobasso       210        Vincent Denson
#  9   10.ª        Campobasso-Giulianova       221          Dino Zandegu
#  10  11.ª        Giulianova-Cesenatico       229            Rudi Altig
#  11  12.ª     Cesenatico-Reggio Emilia       206          Dino Zandegu
# ...
